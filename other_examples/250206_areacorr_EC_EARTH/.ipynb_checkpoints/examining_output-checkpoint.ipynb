# %% [markdown]
# ## Showing the results of the correlation, eof and pca scripts
# a) to show what they do
# b) to check that the outputs are reasonable

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('/glade/u/home/jjeffree/ensemble-analogue-predictability/')
import predictability_tools as pt

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1,memory_limit=0)
client
# Out:
# <Client: 'tcp://127.0.0.1:43703' processes=4 threads=4>

# %%
model_name = 'EC-Earth3_tos_nomean'

# %%
ss = pt.get_025_ss[model_name]()

# %%
ss.sel(lat=slice(-5,5)).mean(('lon','lat')).sel(var='tos',SMILE_M='1').plot()
# Out:
# /glade/work/jjeffree/conda-envs/jj_default2/lib/python3.12/site-packages/distributed/client.py:3362: UserWarning: Sending large graph of size 97.05 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
ss.sel(lat=slice(-5,5)).mean(('lon','lat')).sel(var='tos').plot()
# Out:
# /glade/work/jjeffree/conda-envs/jj_default2/lib/python3.12/site-packages/distributed/client.py:3362: UserWarning: Sending large graph of size 97.11 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
corr_weight = xr.load_dataarray('/glade/derecho/scratch/jjeffree/pca_variations/testing_correlation_weight/'+model_name+'_I4_NINO34_L0/weights.nc')

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
plt.sca(axs[0])
corr_weight.sel(var='tos').plot()
# plt.sca(axs[1])
# corr_weight.sel(var='zos').plot()

# %%
corr_weight = xr.load_dataarray('/glade/work/jjeffree/pca_variations/testing_correlation_weight/'+model_name+'_I1_NINO34_L23/weights.nc')

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
plt.sca(axs[0])
corr_weight.sel(var='tos').plot()
# plt.sca(axs[1])
# corr_weight.sel(var='zos').plot()

# %%
eof = xr.load_dataset('/glade/derecho/scratch/jjeffree/pca_variations/testing_correlation_weight/'+model_name+'_I12_NINO34_L0/'+model_name+'_30P_tos/eof.nc').eof

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
plt.sca(axs[0])
eof.sel(mode=0).sel(var='tos').plot()
# plt.sca(axs[1])
# eof.sel(mode=0).sel(var='zos').plot()

# %%
psn=10
lib_size=500
m='30P'
pca_folder='/glade/work/jjeffree/pca_variations/testing_correlation_weight/'+model_name+'_I1_NINO34_L0/'+model_name+'_'+m+'_tos/'
n_lib_files = np.ceil(pt.n_ensemble_members[model_name]/psn).astype(int)
#lib_members = lib_index.SMILE_M.isel(SMILE_M = slice(lib_mi*lib_size,lib_mi*lib_size+lib_size))
lib_pca_names = [model_name+'_'+m+'_'+str(i*psn)+'-'+str(i*psn+psn)+'M' for i in range(n_lib_files)]
lib_pca = xr.open_mfdataset([pca_folder+'pca_'+lpn+'.nc' for lpn in lib_pca_names],
                                            combine='nested',
                                            concat_dim=('SMILE_M',)).pca.load()
lib_pca.sel(mode=0).plot()
plt.figure()
lib_pca.sel(mode=1).plot()
plt.xticks(np.arange(1,41,5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       3 m='30P'
#       4 pca_folder='/glade/work/jjeffree/pca_variations/testing_correlation_weight/'+model_name+'_I1_NINO34_L0/'+model_name+'_'+m+'_tos/'
# ----> 5 n_lib_files = np.ceil(pt.n_ensemble_members[model_name]/psn).astype(int)
#       6 #lib_members = lib_index.SMILE_M.isel(SMILE_M = slice(lib_mi*lib_size,lib_mi*lib_size+lib_size))
#       7 lib_pca_names = [model_name+'_'+m+'_'+str(i*psn)+'-'+str(i*psn+psn)+'M' for i in range(n_lib_files)]
#
# KeyError: 'EC-Earth3_tos_nomean'

# %%
pt.n_ensemble_members
# Out:
# {'CESM2-LE_025': 100,
#  'ACCESS-ESM1-5': 40,
#  'MPI-GE': 100,
#  'MIROC6': 50,
#  'CanESM5': 40,
#  'IPSL-CM6A-L': 32,
#  'MIROC-ES2L': 30,
#  'ERSSTv5': 1,
#  'OISST-AVISO': 1,
#  'GFDL-ES2M': 30,
#  'MPI-CMIP6': 50,
#  'GFDL-CM2-1': 40,
#  'CESM1_pi': 18,
#  'EC_Earth3_tos': 22,
#  'CESM2-LE_nomean': 100,
#  'ACCESS-ESM1-5_nomean': 40,
#  'MPI-GE_nomean': 100,
#  'MIROC6_nomean': 50,
#  'CanESM5_nomean': 40,
#  'IPSL-CM6A-L_nomean': 32,
#  'MIROC-ES2L_nomean': 30,
#  'ERSSTv5_nomean': 1,
#  'OISST-AVISO_nomean': 1,
#  'GFDL-ES2M_nomean': 30,
#  'MPI-CMIP6_nomean': 50,
#  'EC_Earth3_tos_nomean': 22}

# %%
fct = xr.open_mfdataset('/glade/work/jjeffree/results/multiindex/'+model_name+'_tos_zos/*.nc')

# %%
mse = ((fct.verification-fct.forecast)**2).mean(('Y','pred_SMILE_M','lib_mi')).load()
r = xr.corr(fct.verification,fct.forecast,('Y','pred_SMILE_M','lib_mi')).load()

# %%
fct.mask
# Out:
# <xarray.DataArray 'mask' (mask: 3)> Size: 72B
# array(['30P', '30P30A', '30P30I'], dtype='<U6')
# Coordinates:
#   * mask     (mask) <U6 72B '30P' '30P30A' '30P30I'

# %%
fig, ax = plt.subplots(1,3,figsize=(14,10))
for i in range(3):
    plt.sca(ax[i])
    r.isel(index_lon=i,mask=0).T.plot(vmin=0,vmax=1)

# %%
fig, ax = plt.subplots(1,3,figsize=(14,10))
for i in range(3):
    plt.sca(ax[i])
    r1 =r.isel(index_lon=i).sel(mask='10P')
    r2 =r.isel(index_lon=i).sel(mask='5P')
    np.tanh(np.arctanh(r1)-np.arctanh(r2)).T.plot(vmin=-0.1,vmax=0.1,cmap='BrBG')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '10P'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexes.py:773, in PandasIndex.sel(self, labels, method, tolerance)
#     772 try:
# --> 773     indexer = self.index.get_loc(label_value)
#     774 except KeyError as e:
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: '10P'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       2 for i in range(3):
#       3     plt.sca(ax[i])
# ----> 4     r1 =r.isel(index_lon=i).sel(mask='10P')
#       5     r2 =r.isel(index_lon=i).sel(mask='5P')
#       6     np.tanh(np.arctanh(r1)-np.arctanh(r2)).T.plot(vmin=-0.1,vmax=0.1,cmap='BrBG')
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataarray.py:1643, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1527 def sel(
#    1528     self,
#    1529     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1533     **indexers_kwargs: Any,
#    1534 ) -> Self:
#    1535     """Return a new DataArray whose data is given by selecting index
#    1536     labels along the specified dimension(s).
#    1537
#    (...)
#    1641     Dimensions without coordinates: points
#    1642     """
# -> 1643     ds = self._to_temp_dataset().sel(
#    1644         indexers=indexers,
#    1645         drop=drop,
#    1646         method=method,
#    1647         tolerance=tolerance,
#    1648         **indexers_kwargs,
#    1649     )
#    1650     return self._from_temp_dataset(ds)
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataset.py:3125, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3057 """Returns a new dataset with each array indexed by tick labels
#    3058 along the specified dimension(s).
#    3059
#    (...)
#    3122
#    3123 """
#    3124 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 3125 query_results = map_index_queries(
#    3126     self, indexers=indexers, method=method, tolerance=tolerance
#    3127 )
#    3129 if drop:
#    3130     no_scalar_variables = {}
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexing.py:192, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     190         results.append(IndexSelResult(labels))
#     191     else:
# --> 192         results.append(index.sel(labels, **options))
#     194 merged = merge_sel_results(results)
#     196 # drop dimension coordinates found in dimension indexers
#     197 # (also drop multi-index if any)
#     198 # (.sel() already ensures alignment)
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexes.py:775, in PandasIndex.sel(self, labels, method, tolerance)
#     773                 indexer = self.index.get_loc(label_value)
#     774             except KeyError as e:
# --> 775                 raise KeyError(
#     776                     f"not all values found in index {coord_name!r}. "
#     777                     "Try setting the `method` keyword argument (example: method='nearest')."
#     778                 ) from e
#     780 elif label_array.dtype.kind == "b":
#     781     indexer = label_array
#
# KeyError: "not all values found in index 'mask'. Try setting the `method` keyword argument (example: method='nearest')."

# %%
fig, ax = plt.subplots(1,3,figsize=(14,10))
for i in range(3):
    plt.sca(ax[i])
    r1 =r.isel(index_lon=i).sel(mask='30P30A')
    r2 =r.isel(index_lon=i).sel(mask='30P')
    np.tanh(np.arctanh(r1)-np.arctanh(r2)).T.plot(vmin=-0.1,vmax=0.1,cmap='BrBG')

# %%
fig, ax = plt.subplots(1,3,figsize=(14,10))
for i in range(3):
    plt.sca(ax[i])
    r1 =r.isel(index_lon=i).sel(mask='30P30I')
    r2 =r.isel(index_lon=i).sel(mask='30P')
    np.tanh(np.arctanh(r1)-np.arctanh(r2)).T.plot(vmin=-0.1,vmax=0.1,cmap='BrBG')

# %%
50*2.5
# Out:
# 125.0

# %%
pt.mask_dict['60P'].sum()/pt.mask_dict['G'].sum()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(0.37271689)

# %%
pt.mask_definitions.pacific_mask.where(np.abs(pt.mask_definitions.pacific_mask['lat'])>2,-1).plot()

# %%
pt.plot.sailboat(r.sel(index_lon='nino34'),skill_type='corr',N=90*40*5,vlim=(-0.1,0.1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '60P'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexes.py:773, in PandasIndex.sel(self, labels, method, tolerance)
#     772 try:
# --> 773     indexer = self.index.get_loc(label_value)
#     774 except KeyError as e:
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: '60P'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pt.plot.sailboat(r.sel(index_lon='nino34'),skill_type='corr',N=90*40*5,vlim=(-0.1,0.1))
#
# File ~/ensemble-analogue-predictability/predictability_tools/plot.py:322, in sailboat(skill, N, start_mask, later_mask, skill_type, vlim, fig, axs, cb_axs)
#     318 for ax_i in range(len(later_mask)):
#     319     plt.sca(axs[ax_i+1])
# --> 322     r1 = skill.sel(mask=later_mask[ax_i])
#     324     scatter = plt.scatter((r.init_month+r.L*0-5)%12+5,
#     325         r.init_month*0+r.L,
#     326         c=diff_func(r,r1),
#     327         cmap=cmap,marker='s',s=100,vmin=vlim[0],vmax=vlim[1])
#     328     # print(diff_func(r,r1).sel(L=12,init_month=8).load())
#     329     # print(diff_func(1.319,1.28))
#     330     # print('---------')
#     331     # print(r.sel(L=12,init_month=8))
#     332     # print(r1.sel(L=12,init_month=8))
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataarray.py:1643, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1527 def sel(
#    1528     self,
#    1529     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1533     **indexers_kwargs: Any,
#    1534 ) -> Self:
#    1535     """Return a new DataArray whose data is given by selecting index
#    1536     labels along the specified dimension(s).
#    1537
#    (...)
#    1641     Dimensions without coordinates: points
#    1642     """
# -> 1643     ds = self._to_temp_dataset().sel(
#    1644         indexers=indexers,
#    1645         drop=drop,
#    1646         method=method,
#    1647         tolerance=tolerance,
#    1648         **indexers_kwargs,
#    1649     )
#    1650     return self._from_temp_dataset(ds)
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataset.py:3125, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3057 """Returns a new dataset with each array indexed by tick labels
#    3058 along the specified dimension(s).
#    3059
#    (...)
#    3122
#    3123 """
#    3124 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 3125 query_results = map_index_queries(
#    3126     self, indexers=indexers, method=method, tolerance=tolerance
#    3127 )
#    3129 if drop:
#    3130     no_scalar_variables = {}
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexing.py:192, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     190         results.append(IndexSelResult(labels))
#     191     else:
# --> 192         results.append(index.sel(labels, **options))
#     194 merged = merge_sel_results(results)
#     196 # drop dimension coordinates found in dimension indexers
#     197 # (also drop multi-index if any)
#     198 # (.sel() already ensures alignment)
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/indexes.py:775, in PandasIndex.sel(self, labels, method, tolerance)
#     773                 indexer = self.index.get_loc(label_value)
#     774             except KeyError as e:
# --> 775                 raise KeyError(
#     776                     f"not all values found in index {coord_name!r}. "
#     777                     "Try setting the `method` keyword argument (example: method='nearest')."
#     778                 ) from e
#     780 elif label_array.dtype.kind == "b":
#     781     indexer = label_array
#
# KeyError: "not all values found in index 'mask'. Try setting the `method` keyword argument (example: method='nearest')."

# %%
pt.plot.sailboat(r,skill_type='corr',
                 N=90*pt.n_ensemble_members[model_name]*((pt.n_ensemble_members[model_name])//5-1))
# Out:
# array([<Axes: title={'center': '30P'}, xlabel='Initialisation month', ylabel='Lead time (months)'>,
#        <Axes: title={'center': '30P -> 30P30A'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '30P -> 30P30I'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '30P -> 60P'}, xlabel='Initialisation month'>],
#       dtype=object)

# %%
pt.plot.sailboat(mse,skill_type='mse',N=90*40*5,vlim=(-10,10),start_mask='10P',later_mask=('10-30P','30-10P','30P'),)
# Out:
# array([<Axes: title={'center': '10P'}, xlabel='Initialisation month', ylabel='Lead time (months)'>,
#        <Axes: title={'center': '10P -> 10-30P'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '10P -> 30-10P'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '10P -> 30P'}, xlabel='Initialisation month'>],
#       dtype=object)

# %%
pt.plot.sailboat(r,skill_type='corr',
                 start_mask='10P',later_mask=('10-30P','30-10P','30P'),
                 N=90*pt.n_ensemble_members[model_name]*((pt.n_ensemble_members[model_name])//5-1))
# Out:
# array([<Axes: title={'center': '10P'}, xlabel='Initialisation month', ylabel='Lead time (months)'>,
#        <Axes: title={'center': '10P -> 10-30P'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '10P -> 30-10P'}, xlabel='Initialisation month'>,
#        <Axes: title={'center': '10P -> 30P'}, xlabel='Initialisation month'>],
#       dtype=object)
