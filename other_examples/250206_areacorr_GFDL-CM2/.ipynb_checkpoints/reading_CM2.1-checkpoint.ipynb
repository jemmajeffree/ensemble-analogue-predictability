# %% [markdown]
# ## Reading in data from GFDL-CM2.1 and pretending it's an ensemble
# Seems to me that the best way to do this is to make sure it looks like an ensemble before anyone else sees it, and then the rest of the code treats it like an ensemble of separate members and never knew

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('/glade/u/home/jjeffree/ensemble-analogue-predictability/')
import predictability_tools as pt
import os

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1,memory_limit=0)
client
# Out:
# /glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45279 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:38111' processes=1 threads=1>

# %% [markdown]
# #### Should have actually started by checking this out...

# %%
sst = xr.open_dataset('/glade/work/jjeffree/model_data/GFDL-CM2.1/cm2-1_pi_tos_025.nc',chunks={'time':1200})

# %%
sst.sst.sel(lon=280,lat=0,method='nearest').plot()

# %%
sst = xr.open_dataset('/glade/work/jjeffree/model_data/GFDL-CM2.1/cm2-1_pi_tos_025.nc',chunks={'time':1200})

# %%
sst.sst.isel(time=slice(0,120)).mean('time').plot()

# %%
sst.sst.isel(time=slice(12000,12120)).mean('time').plot()

# %%
sst.sst.isel(time=slice(-120,None)).mean('time').plot()

# %%
sst.sst.mean(('lon','lat')).plot()

# %%
ssh = xr.open_dataset('/glade/work/jjeffree/model_data/GFDL-CM2.1/cm2-1_pi_zos_025.nc',chunks={'time':1200})

# %%
ssh.ssh.mean(('lon','lat')).isel(time=slice(1000*12,None)).plot()

# %% [markdown]
# #### Read it in and reshape it

# %%
def get_GFDL_CM2_1_025_ss():

    data_name = 'GFDL-CM2-1'

    tos = xr.open_dataset('/glade/work/jjeffree/model_data/GFDL-CM2-1/cm2-1_pi_tos_025.nc',chunks={'time':1200}).sst
    zos = xr.open_dataset('/glade/work/jjeffree/model_data/GFDL-CM2-1/cm2-1_pi_zos_025.nc',chunks={'time':1200}).ssh
    
    ss = xr.concat((tos,zos),'var').assign_coords({'var':np.array(('tos','zos'))})
    new_time = ss.time.isel(time=slice(None,1200))
    full_model_ss = ss.coarsen(time=1200).construct(time=('SMILE_M','time')).assign_coords({'time':new_time,'SMILE_M':np.arange(1,41,dtype=int)})
    
    means_file = '/glade/work/jjeffree/SMILE_means/'+data_name+'_025.nc'
    if not(os.path.isfile(means_file)):
        pt.SMILE_means(full_model_ss,means_file) ###

    #Strip seasonal variability
    seasonal_mean = xr.load_dataset(means_file).seasonal_mean
    full_model_ss = pt.strip_climatology(full_model_ss,clim=seasonal_mean)

    #Strip global mean
    zos_global_mean = xr.load_dataset(means_file).zos_global_mean
    full_model_ss = full_model_ss.where(~(full_model_ss['var']=='zos'),full_model_ss-zos_global_mean)
    
    expected_dims = ('var','SMILE_M','time','lat','lon')
    for d in full_model_ss.dims:
        if d not in expected_dims:
            full_model_ss = full_model_ss.squeeze(d,drop=True)
    return full_model_ss

# %%
ss = pt.get_GFDL_CM2_1_025_ss()

# %%
xr.corr(ss,ss.roll(time=1)).load()
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-5959' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/client.py:2197> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/client.py", line 2206, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2024-07-22 00:12:48,205 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('mean_chunk-f5b85f2c42846b13e58ff300008add36', 1, 20, 0, 0, 0))" coro=<Worker.execute() done, defined at /glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 xr.corr(ss,ss.roll(time=1)).load()
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataarray.py:1146, in DataArray.load(self, **kwargs)
#    1126 def load(self, **kwargs) -> Self:
#    1127     """Manually trigger loading of this array's data from disk or a
#    1128     remote source into memory and return this array.
#    1129
#    (...)
#    1144     dask.compute
#    1145     """
# -> 1146     ds = self._to_temp_dataset().load(**kwargs)
#    1147     new = self._from_temp_dataset(ds)
#    1148     self._variable = new._variable
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/core/dataset.py:862, in Dataset.load(self, **kwargs)
#     859 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     861 # evaluate all the chunked arrays simultaneously
# --> 862 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     863     *lazy_data.values(), **kwargs
#     864 )
#     866 for k, data in zip(lazy_data, evaluated_data):
#     867     self.variables[k].data = data
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File ~/.conda/envs/jj_default/lib/python3.11/site-packages/dask/base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/jj_default/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/.conda/envs/jj_default/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
xr.corr(ss,ss.roll(SMILE_M=1)).load()
# Out:
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/asyncio/base_events.py", line 650, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/nanny.py", line 981, in run
#     await worker.finished()
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/core.py", line 630, in finished
#     await self._event_finished.wait()
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/asyncio/locks.py", line 213, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/nanny.py", line 1019, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt

# %%
ss.sel(var='zos').mean(('lon','lat')).plot()

# %%
ss.isel(time=12,SMILE_M=0,var=1).plot()

# %%
ss.isel(time=12,SMILE_M=0,var=0).plot()

# %%
ss.isel(time=12,SMILE_M=39,var=0).plot()

# %% [markdown]
# ## Check means

# %%
means = xr.load_dataset('/glade/work/jjeffree/SMILE_means/GFDL-CM2-1_025.nc')

# %%
means.zos_global_mean.plot()

# %%
means.seasonal_mean.sel(var='tos',month=6).plot()
