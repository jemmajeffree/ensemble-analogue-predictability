# %% [markdown]
# ## Reading in data from CESM1 and pretending it's an ensemble
# ### Copied with slight modifications from the GFDL-CM2.1 one
# Seems to me that the best way to do this is to make sure it looks like an ensemble before anyone else sees it, and then the rest of the code treats it like an ensemble of separate members and never knew

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('/glade/u/home/jjeffree/ensemble-analogue-predictability/')
import predictability_tools as pt
import os

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1,memory_limit=0)
client
# Out:
# /glade/work/jjeffree/conda-envs/jj_default2/lib/python3.12/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44127 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:44767' processes=4 threads=4>

# %% [markdown]
# #### Should have actually started by checking this out...

# %%
sst = xr.open_mfdataset('/glade/work/jjeffree/model_data/CESM1/*SST*025.nc',chunks={'time':1200})

# %%
plt.plot(sst.SST.sel(lon=280,lat=0,method='nearest'))

# %%
sst.SST.isel(time=slice(0,120)).mean('time').plot()

# %%
(sst.SST.isel(time=slice(-120,None)).mean('time')-sst.SST.isel(time=slice(0,120)).mean('time')).plot()

# %%
plt.plot(sst.SST.mean(('lon','lat')))

# %%
ssh = xr.open_mfdataset('/glade/work/jjeffree/model_data/CESM1/*SSH*025.nc',chunks={'time':1200})

# %%
21600/1200
# Out:
# 18.0

# %%
ssh
# Out:
# <xarray.Dataset> Size: 31GB
# Dimensions:      (time: 21612, bnds: 2, lat: 72, lon: 144, z_t: 60, z_w: 60)
# Coordinates:
#   * time         (time) object 173kB 0400-02-01 00:00:00 ... 2201-01-01 00:00:00
#   * lon          (lon) float64 1kB 1.25 3.75 6.25 8.75 ... 353.8 356.2 358.8
#   * lat          (lat) float64 576B -88.75 -86.25 -83.75 ... 83.75 86.25 88.75
#   * z_t          (z_t) float32 240B 500.0 1.5e+03 ... 5.125e+05 5.375e+05
#   * z_w          (z_w) float32 240B 0.0 1e+03 2e+03 ... 4.75e+05 5e+05 5.25e+05
# Dimensions without coordinates: bnds
# Data variables: (12/21)
#     time_bnds    (time, bnds) object 346kB dask.array<chunksize=(1200, 2), meta=np.ndarray>
#     ANGLE        (time, lat, lon) float64 2GB dask.array<chunksize=(1200, 72, 144), meta=np.ndarray>
#     ANGLET       (time, lat, lon) float64 2GB dask.array<chunksize=(1200, 72, 144), meta=np.ndarray>
#     DXT          (time, lat, lon) float64 2GB dask.array<chunksize=(1200, 72, 144), meta=np.ndarray>
# ...

# %%
plt.plot(ssh.SSH.mean(('lon','lat')).isel(time=slice(1000*12,None)))
print('Odd undulation, but not problematic')
# Out:
# Odd undulation, but not problematic

# %% [markdown]
# #### Read it in and reshape it

# %%
import glob

# %%
def get_CESM1_pi_025_ss():

    '''Data this reads was generated running the output of these lines:
    print("module load cdo")
    print("TARGET_FILE=/glade/campaign/cgd/cas/nmaher/access_lens/Omon/tos/tos_mon_ACCESS-ESM1-5_historical_r10i1p1f1_g025.nc")
    filenames = glob.glob('/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ocn/proc/tseries/monthly/SST/b.e11.B1850C5CN.f09_g16.005*')
    for f in filenames:
        print("cdo remapdis,$TARGET_FILE "+f+" "+f.split('/')[-1][:-3]+"_025.nc")
    filenames = glob.glob('/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/ocn/proc/tseries/monthly/SSH/b.e11.B1850C5CN.f09_g16.005*')
    for f in filenames:
        print("cdo remapdis,$TARGET_FILE "+f+" "+f.split('/')[-1][:-3]+"_025.nc")
    '''

    data_name = 'CESM1_pi'

    tos = xr.open_mfdataset('/glade/work/jjeffree/model_data/CESM1/*SST*025.nc',chunks={'time':1200}).SST
    zos = xr.open_mfdataset('/glade/work/jjeffree/model_data/CESM1/*SSH*025.nc',chunks={'time':1200}).SSH
    
    ss = xr.concat((tos,zos),'var').assign_coords({'var':np.array(('tos','zos'))})
    
    assert 'CESM' in data_name, "Only correct CESM dates"
    ss = pt.correct_cesm_date(ss)
    
    new_time = ss.time.isel(time=slice(None,1200))
    full_model_ss = ss.coarsen(time=1200,boundary='trim').construct(time=('SMILE_M','time')).assign_coords({'time':new_time,'SMILE_M':np.arange(5,23,dtype=int)})
    
    means_file = '/glade/work/jjeffree/SMILE_means/'+data_name+'_025.nc'
    if not(os.path.isfile(means_file)):
        pt.SMILE_means(full_model_ss,means_file) ###

    #Strip seasonal variability
    seasonal_mean = xr.load_dataset(means_file).seasonal_mean
    full_model_ss = pt.strip_climatology(full_model_ss,clim=seasonal_mean)

    #Strip global mean
    zos_global_mean = xr.load_dataset(means_file).zos_global_mean
    full_model_ss = full_model_ss.where(~(full_model_ss['var']=='zos'),full_model_ss-zos_global_mean)
    
    expected_dims = ('var','SMILE_M','time','lat','lon')
    for d in full_model_ss.dims:
        if d not in expected_dims:
            full_model_ss = full_model_ss.squeeze(d,drop=True)
    return full_model_ss

# %%
ss = get_CESM1_pi_025_ss()

# %%
ss
# Out:
# <xarray.DataArray 'SST' (var: 2, SMILE_M: 18, time: 1200, lat: 72, lon: 144)> Size: 4GB
# dask.array<getitem, shape=(2, 18, 1200, 72, 144), dtype=float64, chunksize=(1, 1, 1200, 72, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 1kB 1.25 3.75 6.25 8.75 ... 351.2 353.8 356.2 358.8
#   * lat      (lat) float64 576B -88.75 -86.25 -83.75 ... 83.75 86.25 88.75
#   * var      (var) <U3 24B 'tos' 'zos'
#   * time     (time) object 10kB 0400-01-01 00:00:00 ... 0499-12-01 00:00:00
#   * SMILE_M  (SMILE_M) int64 144B 5 6 7 8 9 10 11 12 ... 15 16 17 18 19 20 21 22
#     month    (time) int64 10kB dask.array<chunksize=(1200,), meta=np.ndarray>
# Attributes:
#     long_name:            Potential Temperature
#     units:                degC
#     grid_loc:             3111
#     cell_methods:         time: mean
#     cesm_date_corrected:  True

# %%
xr.corr(ss,ss.roll(time=1)).load()
# Out:
# <xarray.DataArray 'SST' ()> Size: 8B
# array(0.76701959)

# %%
xr.corr(ss,ss.roll(SMILE_M=1)).load()
# Out:
# <xarray.DataArray 'SST' ()> Size: 8B
# array(0.05908695)

# %%
plt.pcolormesh(ss.sel(var='zos').mean(('lon','lat')))

# %%
ss.isel(time=12,SMILE_M=0,var=1).plot()

# %%
ss.isel(time=12,SMILE_M=0,var=0).plot()

# %%
ss.isel(time=12,SMILE_M=19,var=0).plot()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 ss.isel(time=12,SMILE_M=19,var=0).plot()
#
# File /glade/work/jjeffree/conda-envs/jj_default2/lib/python3.12/site-packages/xarray/core/dataarray.py:1527, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1522     return self._from_temp_dataset(ds)
#    1524 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1525 # lists, or zero or one-dimensional np.ndarray's
# -> 1527 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1528 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1530 coords = {}
#
# File /glade/work/jjeffree/conda-envs/jj_default2/lib/python3.12/site-packages/xarray/core/variable.py:1034, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
# ...

# %% [markdown]
# ## Check means

# %%
means = xr.load_dataset('/glade/work/jjeffree/SMILE_means/CESM1_pi_025.nc')

# %%
plt.pcolormesh(means.zos_global_mean.isel(z_t=0))
plt.colorbar()

# %%
(means.seasonal_mean.sel(var='tos',month=1)-means.seasonal_mean.sel(var='tos',month=7)).plot()
