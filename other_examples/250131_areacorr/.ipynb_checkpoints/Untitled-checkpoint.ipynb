# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('/glade/derecho/scratch/jjeffree/pca_variations/area_correlation_weight/ACCESS-ESM1-5_nomean_I1_NINO34_L12/weights.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 168kB
# Dimensions:                        (var: 2, lon: 144, lat: 72)
# Coordinates:
#   * var                            (var) <U3 24B 'tos' 'zos'
#     L                              int64 8B ...
#   * lon                            (lon) float64 1kB 1.25 3.75 ... 356.2 358.8
#   * lat                            (lat) float64 576B -88.75 -86.25 ... 88.75
# Data variables:
#     __xarray_dataarray_variable__  (var, lat, lon) float64 166kB ...

# %%
ds.__xarray_dataarray_variable__.sel(var='tos').plot()

# %%
np.cos(np.deg2rad(40))**2
# Out:
# np.float64(0.5868240888334652)

# %%
ds.__xarray_dataarray_variable__.sel(var='zos').plot()
